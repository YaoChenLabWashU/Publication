# %%
# path = ["/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220206_112_8_AChMut_SW_001_analysis_csv_20220510/",
#         "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220207_109_AChMut_SW_001_analysis_csv_20220510/",
#         "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220422_112_AChmtut_SW_001_analysis_csv_20220426/",
#         "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220425_109_AChmut_SW_001_analysis_csv_20220510/",
#         "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220712_PM29_111_Achmut_001_analysis_csv_20220830/"
#        ]

path = ['/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1610/20220219_1610_SW_002_analysis_csv_20220426/results/',
       '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1610/20220314_1610_SW_003_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1610/20220328_1610_SW_005_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1611/20220302_1611_SW_003_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1611/20220316_1611_SW_004_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1611/20220325_1611_SW_005_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1612/20220301_1612_SW_003_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1612/20220315_1612_SW_004_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1612/20220324_1612_SW_005_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1626/20220313_1626_SW_002_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1626/20220318_1626_SW_003_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1626/20220329_1626_SW_004_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1629/20220312_1629_SW_002_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1629/20220323_1629_SW_003_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1629/20220331_1629_SW_004_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1630/20220304_1630_SW_002_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1630/20220319_1630_SW_003_analysis_csv_20220426/results/',
        '/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/Pingchuan_SW_data_20230813_update/1630/20220330_1630_SW_004_analysis_csv_20220426/results/'
       ]

# path = ["/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220206_112_8_AChMut_SW_001_analysis_csv_20220510/results/",
#         "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220207_109_AChMut_SW_001_analysis_csv_20220510/results/"
#        ]

# path = ["/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1630/20220330_1630_SW_004_analysis_csv_20230115/results/"]

# %%
import pandas as pd
import ast
from ast import literal_eval

for i in range(len(path)):
# for i in [0]:
    
    intensity = pd.read_csv(path[i] + "intensity_epoch_analysis.csv")
    lft_emp = pd.read_csv(path[i] + "lft_emp_epoch_analysis.csv")
    
#     intensity = intensity.drop(columns=["state1.1","state1.2","state2.1","state2.2","state3.1","state3.2","state4.1","state4.2"])
#     lft_emp =  lft_emp.drop(columns=["state1.1","state1.2","state2.1","state2.2","state3.1","state3.2","state4.1","state4.2"])
    
    intensity = intensity.drop(0)
    lft_emp =  lft_emp.drop(0)
    
#     intensity = intensity[['state1','state4','state2','state3']]
#     lft_emp = lft_emp[['state1','state4','state2','state3']]
    
    intensity1 = intensity[['state1']]
    intensity2 = intensity[['state2']]
    intensity3 = intensity[['state3']]
    intensity4 = intensity[['state4']]
    
    lft_emp1 = lft_emp[['state1']]
    lft_emp2 = lft_emp[['state2']]
    lft_emp3 = lft_emp[['state3']]
    lft_emp4 = lft_emp[['state4']]
    
    time1_df = intensity[['state1.2']]
    time2_df = intensity[['state2.2']]
    time3_df = intensity[['state3.2']]
    time4_df = intensity[['state4.2']]
    
    time1_df = time1_df.dropna()
    time2_df = time2_df.dropna()
    time3_df = time3_df.dropna()
    time4_df = time4_df.dropna()
    
    time1_df['time_float1'] = time1_df['state1.2'].apply(lambda x: literal_eval(str(x)))
    time1 = pd.DataFrame(time1_df.loc[:,'time_float1'].tolist())
    
    time2_df['time_float2'] = time2_df['state2.2'].apply(lambda x: literal_eval(str(x)))
    time2 = pd.DataFrame(time2_df.loc[:,'time_float2'].tolist())
    
    time3_df['time_float3'] = time3_df['state3.2'].apply(lambda x: literal_eval(str(x)))
    time3 = pd.DataFrame(time3_df.loc[:,'time_float3'].tolist())
    
    time4_df['time_float4'] = time4_df['state4.2'].apply(lambda x: literal_eval(str(x)))
    time4 = pd.DataFrame(time4_df.loc[:,'time_float4'].tolist())
    
    filename_intensity1 = path[i] + "intensity1.csv"
    filename_intensity2 = path[i] + "intensity2.csv"
    filename_intensity3 = path[i] + "intensity3.csv"
    filename_intensity4 = path[i] + "intensity4.csv"
    
    filename_lft1 = path[i] + "lft1.csv"
    filename_lft2 = path[i] + "lft2.csv"
    filename_lft3 = path[i] + "lft3.csv"
    filename_lft4 = path[i] + "lft4.csv"
    
    filename_time1_1 = path[i] + "time1_1.csv"
    filename_time2_1 = path[i] + "time2_1.csv"
    filename_time3_1 = path[i] + "time3_1.csv"
    filename_time4_1 = path[i] + "time4_1.csv"
    
    filename_time1_2 = path[i] + "time1_2.csv"
    filename_time2_2 = path[i] + "time2_2.csv"
    filename_time3_2 = path[i] + "time3_2.csv"
    filename_time4_2 = path[i] + "time4_2.csv"
    
    intensity1.to_csv(filename_intensity1, index=False)
    intensity2.to_csv(filename_intensity2, index=False)
    intensity3.to_csv(filename_intensity3, index=False)
    intensity4.to_csv(filename_intensity4, index=False)
    
    lft_emp1.to_csv(filename_lft1, index=False)
    lft_emp2.to_csv(filename_lft2, index=False)
    lft_emp3.to_csv(filename_lft3, index=False)
    lft_emp4.to_csv(filename_lft4, index=False)
    
    time1[0].to_csv(filename_time1_1, index=False)
    time2[0].to_csv(filename_time2_1, index=False)
    time3[0].to_csv(filename_time3_1, index=False)
    time4[0].to_csv(filename_time4_1, index=False)
    
    time1[1].to_csv(filename_time1_2, index=False)
    time2[1].to_csv(filename_time2_2, index=False)
    time3[1].to_csv(filename_time3_2, index=False)
    time4[1].to_csv(filename_time4_2, index=False)

# %%
# print(time2_df)
time2_df = time2_df.dropna()
time2_df['time_float'] = time2_df['state2.2'].apply(lambda x: literal_eval(str(x)))
time2 = pd.DataFrame(time2_df.loc[:,'time_float'].tolist())
print(time2_df)
# Out:
#               state2.2          time_float
# 1     [12.606, 89.566]    [12.606, 89.566]
# 2     [294.61, 841.54]    [294.61, 841.54]
# 3     [2410.6, 3056.6]    [2410.6, 3056.6]
# 4     [3810.0, 4020.0]    [3810.0, 4020.0]
# 5     [4173.0, 4967.6]    [4173.0, 4967.6]
# 6     [5753.8, 6231.9]    [5753.8, 6231.9]
# 7     [6290.1, 6403.5]    [6290.1, 6403.5]
# 8     [6500.3, 7005.0]    [6500.3, 7005.0]
# 9     [7229.9, 7600.5]    [7229.9, 7600.5]
# 10    [9096.8, 9567.2]    [9096.8, 9567.2]
# 11  [10105.0, 10143.0]  [10105.0, 10143.0]
# 12  [10193.0, 10880.0]  [10193.0, 10880.0]
# 13  [11704.0, 12056.0]  [11704.0, 12056.0]
# 14  [12248.0, 12803.0]  [12248.0, 12803.0]
# 15  [12928.0, 12956.0]  [12928.0, 12956.0]
# 16  [14887.0, 15211.0]  [14887.0, 15211.0]
# 17  [15267.0, 15346.0]  [15267.0, 15346.0]
# 18  [15447.0, 15822.0]  [15447.0, 15822.0]
# 19  [15875.0, 15998.0]  [15875.0, 15998.0]
# 20  [16047.0, 16146.0]  [16047.0, 16146.0]
# 21  [16292.0, 16486.0]  [16292.0, 16486.0]
# ...

# %%
# Out:
# <ipython-input-106-5ad1bc7dcdba>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time1_df['time_float1'] = time1_df['state1.2'].apply(lambda x: literal_eval(str(x)))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-5ad1bc7dcdba> in <module>
#      36     time1 = pd.DataFrame(time1_df.loc[:,'time_float1'].tolist())
#      37
# ---> 38     time2_df['time_float2'] = time2_df['state2.2'].apply(lambda x: literal_eval(str(x)))
#      39     time2 = pd.DataFrame(time2_df.loc[:,'time_float2'].tolist())
#      40
#
# ...

# %%
print(time1_df)
# Out:
#               state1.2         time_float1
# 1      [867.04, 885.4]     [867.04, 885.4]
# 2     [1010.9, 1556.7]    [1010.9, 1556.7]
# 3     [1642.4, 1752.5]    [1642.4, 1752.5]
# 4     [1978.3, 2013.0]    [1978.3, 2013.0]
# 5     [2170.4, 2205.2]    [2170.4, 2205.2]
# 6     [2283.1, 2384.8]    [2283.1, 2384.8]
# 7     [3438.5, 3641.4]    [3438.5, 3641.4]
# 8     [3714.3, 3785.0]    [3714.3, 3785.0]
# 9     [5421.6, 5728.3]    [5421.6, 5728.3]
# 10    [7773.6, 8275.5]    [7773.6, 8275.5]
# 11    [8373.4, 8631.5]    [8373.4, 8631.5]
# 12    [8744.8, 9071.3]    [8744.8, 9071.3]
# 13   [9813.2, 10080.0]   [9813.2, 10080.0]
# 14  [10905.0, 10991.0]  [10905.0, 10991.0]
# 15  [11284.0, 11392.0]  [11284.0, 11392.0]
# 16  [11512.0, 11679.0]  [11512.0, 11679.0]
# 17  [12172.0, 12223.0]  [12172.0, 12223.0]
# 18  [12981.0, 13008.0]  [12981.0, 13008.0]
# 19  [13324.0, 13683.0]  [13324.0, 13683.0]
# 20  [13881.0, 13980.0]  [13881.0, 13980.0]
# 21  [14104.0, 14127.0]  [14104.0, 14127.0]
# ...

# %%
import ast
from ast import literal_eval
# time = pd.read_csv("time1.csv")
time1_df['time_float'] = time1_df['state1.2'].apply(lambda x: literal_eval(str(x)))
split_df = pd.DataFrame(time1['time_float'].tolist())
print(split_df)
# split_df[0].to_csv('time_1_1.csv')
# split_df[1].to_csv('time_1_2.csv')
# Out:
# <ipython-input-102-9d221d546e6a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time1_df['time_float'] = time1_df['state1.2'].apply(lambda x: literal_eval(str(x)))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-9d221d546e6a> in <module>
#       3 # time = pd.read_csv("time1.csv")
#       4 time1_df['time_float'] = time1_df['state1.2'].apply(lambda x: literal_eval(str(x)))
# ----> 5 split_df = pd.DataFrame(time1['time_float'].tolist())
#       6 print(split_df)
#       7 # split_df[0].to_csv('time_1_1.csv')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
# ...

# %%
import pandas as pd
i = 1
intensity = pd.read_csv(path[i] + "intensity_epoch_analysis.csv")
lft_emp = pd.read_csv(path[i] + "lft_emp_epoch_analysis.csv")
intensity = intensity.drop(columns=["state1.1","state1.2","state2.1","state2.2","state3.1","state3.2","state4.1","state4.2"])
lft_emp =  lft_emp.drop(columns=["state1.1","state1.2","state2.1","state2.2","state3.1","state3.2","state4.1","state4.2"])
intensity = intensity.drop(0)
lft_emp =  lft_emp.drop(0)

# %%
print(lft_emp)
# Out:
#                 state1              state2   state3              state4
# 1               4.1672              4.1703   4.2323              4.1649
# 2               4.2136              4.1532    4.235  4.1789000000000005
# 3    4.229150000000001              4.1513  4.23255   4.181150000000001
# 4              4.21255               4.157   4.2362              4.1993
# 5              4.18815              4.1413   4.2303              4.1708
# 6              4.20765              4.1577   4.2259              4.1681
# 7               4.1894             4.15975   4.2176   4.196949999999999
# 8              4.18705              4.1516   4.2632              4.1704
# 9              4.18385              4.1532   4.2597              4.1735
# 10              4.2009               4.159   4.2531  4.2040500000000005
# 11              4.2199              4.1608   4.2552              4.1839
# 12             4.20155              4.1928      NaN              4.1855
# ...
