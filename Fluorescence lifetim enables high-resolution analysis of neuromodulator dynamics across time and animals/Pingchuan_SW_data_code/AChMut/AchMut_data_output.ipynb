# %%
path = ["/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220206_112_8_AChMut_SW_001_analysis_csv_20220510/",
        "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220207_109_AChMut_SW_001_analysis_csv_20220510/",
        "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220422_112_AChmtut_SW_001_analysis_csv_20220426/",
        "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220425_109_AChmut_SW_001_analysis_csv_20220510/",
        "/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/ACh_mut/20220712_PM29_111_Achmut_001_analysis_csv_20220830/"
       ]

path = ["/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1610/20220219_1610_SW_002_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1610/20220314_1610_SW_003_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1610/20220328_1610_SW_005_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1611/20220302_1611_SW_003_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1611/20220316_1611_SW_004_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1611/20220325_1611_SW_005_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1612/20220301_1612_SW_003_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1612/20220315_1612_SW_004_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1612/20220324_1612_SW_005_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1626/20220313_1626_SW_002_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1626/20220318_1626_SW_003_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1626/20220329_1626_SW_004_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1627/20220317_1627_SW_002_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1627/20220322_1627_SW_003_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1627/20220402_1627_SW_004_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1629/20220312_1629_SW_002_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1629/20220323_1629_SW_003_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1629/20220331_1629_SW_004_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1630/20220304_1630_SW_002_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1630/20220319_1630_SW_003_analysis_csv_20220426/results/",
"/Users/pingchuanma/Desktop/ChenLab_Data/FLP_data_sleep/1630/20220330_1630_SW_004_analysis_csv_20220426/results/"]

# %%
import pandas as pd
for i in range(len(path)):
    
    intensity = pd.read_csv(path[i] + "intensity_epoch_analysis.csv")
    lft_emp = pd.read_csv(path[i] + "lft_emp_epoch_analysis.csv")
    
    intensity = intensity.drop(columns=["state1.1","state1.2","state2.1","state2.2","state3.1","state3.2","state4.1","state4.2"])
    lft_emp =  lft_emp.drop(columns=["state1.1","state1.2","state2.1","state2.2","state3.1","state3.2","state4.1","state4.2"])
    
    intensity = intensity.drop(0)
    lft_emp =  lft_emp.drop(0)
    
    intensity = intensity[['state1','state4','state2','state3']]
    lft_emp = lft_emp[['state1','state4','state2','state3']]
    
    intensity1 = intensity[['state1']]
    intensity2 = intensity[['state2']]
    intensity3 = intensity[['state3']]
    intensity4 = intensity[['state4']]
    
    lft_emp1 = lft_emp[['state1']]
    lft_emp2 = lft_emp[['state2']]
    lft_emp3 = lft_emp[['state3']]
    lft_emp4 = lft_emp[['state4']]
    
    filename_intensity1 = path[i] + "intensity1.csv"
    filename_intensity2 = path[i] + "intensity2.csv"
    filename_intensity3 = path[i] + "intensity3.csv"
    filename_intensity4 = path[i] + "intensity4.csv"
    filename_lft1 = path[i] + "lft1.csv"
    filename_lft2 = path[i] + "lft2.csv"
    filename_lft3 = path[i] + "lft3.csv"
    filename_lft4 = path[i] + "lft4.csv"
    
    intensity1.to_csv(filename_intensity1, index=False)
    intensity2.to_csv(filename_intensity2, index=False)
    intensity3.to_csv(filename_intensity3, index=False)
    intensity4.to_csv(filename_intensity4, index=False)
    
    lft_emp1.to_csv(filename_lft1, index=False)
    lft_emp2.to_csv(filename_lft2, index=False)
    lft_emp3.to_csv(filename_lft3, index=False)
    lft_emp4.to_csv(filename_lft4, index=False)

# %%
import pandas as pd
i = 1
intensity = pd.read_csv(path[i] + "intensity_epoch_analysis.csv")
lft_emp = pd.read_csv(path[i] + "lft_emp_epoch_analysis.csv")
intensity = intensity.drop(columns=["state1.1","state1.2","state2.1","state2.2","state3.1","state3.2","state4.1","state4.2"])
lft_emp =  lft_emp.drop(columns=["state1.1","state1.2","state2.1","state2.2","state3.1","state3.2","state4.1","state4.2"])
intensity = intensity.drop(0)
lft_emp =  lft_emp.drop(0)

# %%
print(lft_emp)
# Out:
#                 state1              state2   state3              state4
# 1               4.1672              4.1703   4.2323              4.1649
# 2               4.2136              4.1532    4.235  4.1789000000000005
# 3    4.229150000000001              4.1513  4.23255   4.181150000000001
# 4              4.21255               4.157   4.2362              4.1993
# 5              4.18815              4.1413   4.2303              4.1708
# 6              4.20765              4.1577   4.2259              4.1681
# 7               4.1894             4.15975   4.2176   4.196949999999999
# 8              4.18705              4.1516   4.2632              4.1704
# 9              4.18385              4.1532   4.2597              4.1735
# 10              4.2009               4.159   4.2531  4.2040500000000005
# 11              4.2199              4.1608   4.2552              4.1839
# 12             4.20155              4.1928      NaN              4.1855
# ...
